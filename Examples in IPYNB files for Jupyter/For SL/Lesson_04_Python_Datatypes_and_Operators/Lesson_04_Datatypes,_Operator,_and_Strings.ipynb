# %% [markdown]
# # Data Types

# %%
x = 20
y = 40
z = 60

# %%
x,y,z
# Out:
# (20, 40, 60)

# %%
a = 20.5
b = 33.55
c = 40.501

# %%
x,y,z,a,b,c
# Out:
# (20, 40, 60, 20.5, 33.55, 40.501)

# %%
type(x),type(y),type(a)
# Out:
# (int, int, float)

# %%
names = 'america'

# %%
type(names)
# Out:
# str

# %%
val = True

# %%
type(val)
# Out:
# bool

# %%
names
# Out:
# 'america'

# %%
names = "john ross marie"

# %%
names = ["john","ross","marie",777,10.98]

# %%
type(names)
# Out:
# list

# %%
names1 = ["john","ross","marie",777,10.98,777,777,"john"]

# %%
type(names1)
# Out:
# list

# %%
names2 = ("john","ross","marie","marie")

# %%
type(names2)
# Out:
# tuple

# %%
names3 = set(names1)

# %%
names3
# Out:
# {10.98, 777, 'john', 'marie', 'ross'}

# %%
type(names3)
# Out:
# set

# %%
names4 = {"name": "john","loc":"nyc"}

# %%
type(names4)
# Out:
# dict

# %%
print(names,type(names),names1,type(names1),names2,type(names2))
# Out:
# ['john', 'ross', 'marie', 777, 10.98] <class 'list'> ['john', 'ross', 'marie', 777, 10.98, 777, 777, 'john'] <class 'list'> ('john', 'ross', 'marie', 'marie') <class 'tuple'>

# %%
print(names,type(names),names1,type(names1),names2,type(names2),end='||')
# Out:
# ['john', 'ross', 'marie', 777, 10.98] <class 'list'> ['john', 'ross', 'marie', 777, 10.98, 777, 777, 'john'] <class 'list'> ('john', 'ross', 'marie', 'marie') <class 'tuple'>||

# %%
x = 34 ; y = 67.89 ; z = True
print("x= ", x, '\ty= ', y, '\tz= ', z)
# Out:
# x=  34 	y=  67.89 	z=  True

# %%
x = 34 ; y = 67.89 ; z = True
print("x: ", x, '\ny: ', y, '\nz: ', z)
# Out:
# x:  34
# y:  67.89
# z:  True

# %%
print('Type of \nx = ', type(x), '\ty = ', type(y), '\tz = ', type(z))
# Out:
# Type of
# x =  <class 'int'> 	y =  <class 'float'> 	z =  <class 'bool'>

# %%
var = 'abc'
print('var = ', var)
print('type of var ', type(var))

# %%
x is y, x == y
# Out:
# (False, False)

# %%
a = 100

# %%
b = 100

# %%
a == b
# Out:
# True

# %%
print(id(a),id(b))
# Out:
# 1784257842512 1784257842512

# %%
a is b
# Out:
# True

# %%
prompt
# Out:
# 'what is artificial intelligence'

# %%
names
# Out:
# ['john', 'ross', 'marie', 777, 10.98]

# %%
names1
# Out:
# ['john', 'ross', 'marie', 777, 10.98, 777, 777, 'john']

# %%
x, y, z
# Out:
# (34, 67.89, True)

# %%
x+y
# Out:
# 101.89

# %%
y+z
# Out:
# 68.89

# %%
x + prompt
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 x + prompt
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
prompt*x
# Out:
# 'what is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligencewhat is artificial intelligence'

# %%
y/x
# Out:
# 1.996764705882353

# %%
y//x
# Out:
# 1.0

# %%
y%x
# Out:
# 33.89

# %%
x**y
# Out:
# 9.37785855397842e+103

# %% [markdown]
# ## Data Type Conversion
# Data type conversion in Python refers to the process of converting a value from one data type to another.

# %%
x = 45.77
int(x)
# Out:
# 45

# %%
str(x)

# %%
bool(x)
# Out:
# True

# %%
y = '45.88'

# %%
float(y)
# Out:
# 45.88

# %%
int(float(y))
# Out:
# 45

# %% [markdown]
# ## Checking References
# Checking references in Python involves determining whether two variables reference the same object in memory using the id() function.

# %%
x = 34
y = x
print('x = ', x, ';  id of x = ', id(x))
print('y = ', y, ';  id of y = ', id(y))
# Out:
# x =  34 ;  id of x =  140563811108112
# y =  34 ;  id of y =  140563811108112

# %%
x = 65
print('x = ', x, ';  id of x = ', id(x))
print('y = ', y, ';  id of y = ', id(y))
# Out:
# x =  65 ;  id of x =  140563811109104
# y =  34 ;  id of y =  140563811108112

# %%
y = 78
print('x = ', x, ';  id of x = ', id(x))
print('y = ', y, ';  id of y = ', id(y))
# Out:
# x =  65 ;  id of x =  140563811109104
# y =  78 ;  id of y =  140563811109520

# %% [markdown]
# # Arithmetic Operators

# %%
x = 50
y = 4

# %%
print('Sum of x & y                   : ', x + y)
print('Difference between x & y       : ', x - y)
print('Product of x & y               : ', x * y)
print('Division of x by y             : ', x / y)
# Out:
# Sum of x & y                   :  54
# Difference between x & y       :  46
# Product of x & y               :  200
# Division of x by y             :  12.5

# %%
print('Remainder of x divided by y    : ', x % y)
print('Floor Division x divided by y  : ', x // y)
print('Exponential value for x raised to power y : ', x ** y)
# Out:
# Remainder of x divided by y    :  2
# Floor Division x divided by y  :  12
# Exponential value for x raised to power y :  6250000

# %% [markdown]
# # Arithmetic Assignment Operators

# %%
a = 10
print('Present value of a = ', a )
# Out:
# Present value of a =  10

# %%
a += 5
print('Updated value of a = ', a )
# Out:
# Updated value of a =  15

# %%
a = 10
print('Present value of a = ', a )
print('Present id of a = ', id(a))
# Out:
# Present value of a =  10
# Present id of a =  140563811107344

# %%
a += 15
print('Updated value of a = ', a )
print('Updated id of a = ', id(a))
# Out:
# Updated value of a =  25
# Updated id of a =  140563811107824

# %% [markdown]
# # Comparison Operator

# %%
a = 20
b = 20
print('a = ', a, '  b = ', b)
print('a == b  : ', a == b)
# Out:
# a =  20   b =  20
# a == b  :  True

# %%
a = 20
b = 30
print('a = ', a, '  b = ', b)
print('a != b  : ', a != b)
# Out:
# a =  20   b =  30
# a != b  :  True

# %%
a = 40
b = 30
print('a = ', a, '  b = ', b)
print('a <= b  : ', a <= b)
# Out:
# a =  40   b =  30
# a <= b  :  False

# %%
a = 30
b = 30
print('a = ', a, '  b = ', b)
print('a >= b  : ', a >= b)
# Out:
# a =  30   b =  30
# a >= b  :  True

# %% [markdown]
# # Logical Operators

# %%
a = 30
b = 30
print('a = ', a, '  b = ', b)
print('a < b            : ', a < b)
print('a == b           : ', a == b)
# Out:
# a =  30   b =  30
# a < b            :  False
# a == b           :  True

# %%
print('a < b and a == b : ', a < b and a == b)
# Out:
# a < b and a == b :  False

# %%
a = 30
b = 30
print('a = ', a, '  b = ', b)
print('a < b           : ', a < b)
print('a == b          : ', a == b)
# Out:
# a =  30   b =  30
# a < b           :  False
# a == b          :  True

# %%
print('a < b or a == b : ', a < b or a == b)
# Out:
# a < b or a == b :  True

# %%
a = 40
print('a = ', a)
print('a < 50      : ' , a < 50 )
# Out:
# a =  40
# a < 50      :  True

# %%
print('not a < 50  : ' , not(a < 50))
# Out:
# not a < 50  :  False

# %% [markdown]
# # Miscellaneous Operators

# %% [markdown]
# ### Identity Operators

# %%
a = ['a', 'b', 'c']
b = ['a', 'b', 'c']
print('a is b' , a is b)
# Out:
# a is b False

# %%
a = ['a', 'b', 'c']
b =  a
print('a is b' , a is b)
# Out:
# a is b True

# %%
id(a) == id(b)
# Out:
# True

# %%
a = ['a', 'b', 'c']
b = ['a', 'b', 'c']
print('a is not b' , a is not b)
# Out:
# a is not b True

# %% [markdown]
# ### Membership Operators

# %%
x = 'a'
y = 'Dictionary'
print(x , ' in "', y, '"')
print( x in y)
# Out:
# a  in " Dictionary "
# True

# %%
x = 'a'
y = 'Dictionary'
print(x , ' in "', y, '"')
print( x not in y)
# Out:
# a  in " Dictionary "
# False

# %%
a = [20, 45, 10]
10 in a
# Out:
# True

# %%
a = [20, 45, 10]
10 not in a
# Out:
# False

# %% [markdown]
# # Strings in Python

# %%
message_1 = 'Hi! Welcome to Python Programming!!'
message_2 = "Hi! Welcome to Python Programming!!"
print(message_1)
print(message_2)
# Out:
# Hi! Welcome to Python Programming!!
# Hi! Welcome to Python Programming!!

# %%
message_1 = 'Hi! Welcome to "Python Programming"!!'
message_2 = "Hi! Welcome to 'Python Programming'!!"
print(message_1)
print(message_2)
# Out:
# Hi! Welcome to "Python Programming"!!
# Hi! Welcome to 'Python Programming'!!

# %% [markdown]
# # String Methods

# %%
string = 'She seLLs sEa SHELLS oN tHe SeA sHoRe.'
upper_case = string.upper()
print(upper_case)
# Out:
# SHE SELLS SEA SHELLS ON THE SEA SHORE.

# %%
lower_case = string.lower()
print(lower_case)
# Out:
# she sells sea shells on the sea shore.

# %%
sentence = string.capitalize()
print(sentence)
# Out:
# She sells sea shells on the sea shore.

# %%
word_upper = string.title()
word_upper
# Out:
# 'She Sells Sea Shells On The Sea Shore.'
